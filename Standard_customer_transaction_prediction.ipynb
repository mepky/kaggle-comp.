# %% [markdown]
# <a href="https://colab.research.google.com/github/mepky/kaggle-comp./blob/master/Standard_customer_transaction_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q kaggle
# !mkdir -p ~/.kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5aafd9a8-7c15-4fbf-abf8-87c834b32447" name="files[]" multiple disabled />
#      <output id="result-5aafd9a8-7c15-4fbf-abf8-87c834b32447">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"praveeny20","key":"a4ab2780819acd1c99611cfa46ad48a7"}'}

# %%
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ref                                                          title                                                size  lastUpdated          downloadCount
# -----------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# ronitf/heart-disease-uci                                     Heart Disease UCI                                     3KB  2018-06-25 11:33:56          21833
# russellyates88/suicide-rates-overview-1985-to-2016           Suicide Rates Overview 1985 to 2016                 396KB  2018-12-01 19:18:25          16237
# karangadiya/fifa19                                           FIFA 19 complete player dataset                       2MB  2018-12-21 03:52:59          18253
# lava18/google-play-store-apps                                Google Play Store Apps                                2MB  2019-02-03 13:55:47          45787
# bigquery/crypto-ethereum-classic                             Ethereum Classic Blockchain                          70GB  2019-03-20 23:21:25              0
# iarunava/cell-images-for-detecting-malaria                   Malaria Cell Images Dataset                         337MB  2018-12-05 05:40:21           3485
# jessicali9530/stanford-dogs-dataset                          Stanford Dogs Dataset                               735MB  2019-02-13 05:45:25           1882
# noriuk/us-education-datasets-unification-project             U.S. Education Datasets: Unification Project         85MB  2019-03-02 18:41:52           2628
# jutrera/stanford-car-dataset-by-classes-folder               Stanford Car Dataset by classes folder                2GB  2018-07-02 07:35:45           2472
# anokas/kuzushiji                                             Kuzushiji-MNIST                                     318MB  2018-12-17 01:19:31            687
# pavansanagapati/urban-sound-classification                   Urban Sound Classification                            6GB  2018-06-16 13:44:36           1997
# vjchoudhary7/customer-segmentation-tutorial-in-python        Mall Customer Segmentation Data                       2KB  2018-08-11 07:23:02           5624
# safegraph/visit-patterns-by-census-block-group               Consumer & Visitor Insights For Neighborhoods        66MB  2018-12-19 21:31:50           1083
# mdhrumil/top-5000-youtube-channels-data-from-socialblade     Top 5000 Youtube channels data from Socialblade.    128KB  2018-09-09 14:05:54           6514
# safegraph/census-block-group-american-community-survey-data  Census Block Group American Community Survey Data     2GB  2018-12-22 00:29:56            583
# mohansacharya/graduate-admissions                            Graduate Admissions                                   9KB  2018-12-28 10:07:14          15944
# jessicali9530/celeba-dataset                                 CelebFaces Attributes (CelebA) Dataset                1GB  2018-06-01 20:08:48           5731
# cityofLA/los-angeles-parking-citations                       Los Angeles Parking Citations                       255MB  2019-03-30 22:17:01           2667
# rmisra/news-headlines-dataset-for-sarcasm-detection          News Headlines Dataset For Sarcasm Detection          2MB  2018-06-09 22:14:56           2165
# fivethirtyeight/fivethirtyeight-comic-characters-dataset     FiveThirtyEight Comic Characters Dataset            577KB  2019-03-26 15:01:15           1894

# %%
# !kaggle competitions download -c santander-customer-transaction-prediction
# Out:
# Downloading train.csv.zip to /content
#  87% 107M/122M [00:00<00:00, 125MB/s]
# 100% 122M/122M [00:00<00:00, 152MB/s]
# Downloading sample_submission.csv.zip to /content
#   0% 0.00/463k [00:00<?, ?B/s]
# 100% 463k/463k [00:00<00:00, 139MB/s]
# Downloading test.csv.zip to /content
#  93% 113M/122M [00:00<00:00, 137MB/s]
# 100% 122M/122M [00:00<00:00, 137MB/s]

# %%
# !ls
# Out:
# sample_data  sample_submission.csv.zip	test.csv.zip  train.csv.zip

# %%
# !unzip  train.csv.zip
# Out:
# Archive:  train.csv.zip
#   inflating: train.csv

# %%
# !unzip test.csv.zip
# Out:
# Archive:  test.csv.zip
#   inflating: test.csv

# %%
# !unzip sample_submission.csv.zip
# Out:
# Archive:  sample_submission.csv.zip
#   inflating: sample_submission.csv

# %% [markdown]
# Above all command is used for import the dataset from kaggle

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import lightgbm as lgb
import seaborn as sns
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import dataset

# %%
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')

# %%
features = [c for c in train.columns if c not in ['ID_code', 'target']]

# %% [markdown]
# ### Describe dataset

# %%
train.describe()
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# 25%         5.254075       9.883175     -11.200350       4.767700
# 50%         6.825000      11.108250      -4.833150       5.385100
# 75%         8.324100      12.261125       0.924800       6.003000
# max        13.188300      16.671400      17.251600       8.447700
#
#                var_7          var_8      ...              var_190  \
# count  200000.000000  200000.000000      ...        200000.000000
# mean       16.545850       0.284162      ...             3.234440
# std         3.418076       3.332634      ...             4.559922
# min         5.349700     -10.505500      ...           -14.093300
# 25%        13.943800      -2.317800      ...            -0.058825
# 50%        16.456800       0.393700      ...             3.203600
# 75%        19.102900       2.937900      ...             6.406200
# max        27.691800      10.151300      ...            18.440900
#
#              var_191        var_192        var_193        var_194  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        7.438408       1.927839       3.331774      17.993784
# std         3.023272       1.478423       3.992030       3.135162
# min        -2.691700      -3.814500     -11.783400       8.694400
# 25%         5.157400       0.889775       0.584600      15.629800
# 50%         7.347750       1.901300       3.396350      17.957950
# 75%         9.512525       2.949500       6.205800      20.396525
# max        16.716500       8.402400      18.281800      27.928800
#
#              var_195        var_196        var_197        var_198  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       -0.142088       2.303335       8.908158      15.870720
# std         1.429372       5.454369       0.921625       3.010945
# min        -5.261000     -14.209600       5.960600       6.299300
# 25%        -1.170700      -1.946925       8.252800      13.829700
# 50%        -0.172700       2.408900       8.888200      15.934050
# 75%         0.829600       6.556725       9.593300      18.064725
# max         4.272900      18.321500      12.000400      26.079100
#
#              var_199
# count  200000.000000
# mean       -3.326537
# std        10.438015
# min       -38.852800
# 25%       -11.208475
# 50%        -2.819550
# 75%         4.836800
# max        28.500700
#
# [8 rows x 201 columns]

# %%
train.columns
# Out:
# Index(['ID_code', 'target', 'var_0', 'var_1', 'var_2', 'var_3', 'var_4',
#        'var_5', 'var_6', 'var_7',
#        ...
#        'var_190', 'var_191', 'var_192', 'var_193', 'var_194', 'var_195',
#        'var_196', 'var_197', 'var_198', 'var_199'],
#       dtype='object', length=202)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Columns: 202 entries, ID_code to var_199
# dtypes: float64(200), int64(1), object(1)
# memory usage: 308.2+ MB

# %% [markdown]
# ### Checking Null value in training dataset

# %%
#train.isnull().sum()

# %% [markdown]
# Fortunately here is no null value in datset

# %% [markdown]
# ### Data visualization

# %%
target = train['target']
train = train.drop(["ID_code", "target"], axis=1)
sns.set_style('whitegrid')
sns.countplot(target)

# %%
plt.figure(figsize=(16,6))
plt.title("Distribution of mean values per row in the train and test set")
sns.distplot(train[features].mean(axis=1),color="black", kde=True,bins=120, label='train')
sns.distplot(test[features].mean(axis=1),color="red", kde=True,bins=120, label='test')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.title("Distribution of mean values per column in the train and test set")
sns.distplot(train[features].mean(axis=0),color="black", kde=True,bins=120, label='train')
sns.distplot(test[features].mean(axis=0),color="red", kde=True,bins=120, label='test')
plt.legend();plt.show()

# %%
plt.figure(figsize=(16,6))
plt.title("Distribution of std values per rows in the train and test set")
sns.distplot(train[features].std(axis=1),color="blue",kde=True,bins=120, label='train')
sns.distplot(test[features].std(axis=1),color="green", kde=True,bins=120, label='test')
plt.legend(); plt.show()

# %%
plt.figure(figsize=(16,6))
plt.title("Distribution of mean values per column in the train and test set")
sns.distplot(train[features].mean(axis=0),color="blue", kde=True,bins=120, label='train')
sns.distplot(test[features].mean(axis=0),color="green", kde=True,bins=120, label='test')
plt.legend();plt.show()

# %% [markdown]
# Dataset having huge columns so lets try dimesionality reduction

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
train_scaled = scaler.fit_transform(train)         
PCA_train_x = PCA(2).fit_transform(train_scaled)
plt.scatter(PCA_train_x[:, 0], PCA_train_x[:, 1], c=target, cmap="copper_r")
plt.axis('off')
plt.colorbar()
plt.show()

# %% [markdown]
# From here we are not getting any clue to reduce the dimension of data

# %%
from sklearn.decomposition import KernelPCA

lin_pca = KernelPCA(n_components = 2, kernel="linear", fit_inverse_transform=True)
rbf_pca = KernelPCA(n_components = 2, kernel="rbf", gamma=0.0433, fit_inverse_transform=True)
sig_pca = KernelPCA(n_components = 2, kernel="sigmoid", gamma=0.001, coef0=1, fit_inverse_transform=True)

# %%
plt.figure(figsize=(11, 4))
for subplot, pca, title in ((131, lin_pca, "Linear kernel"), (132, rbf_pca, "RBF kernel, $\gamma=0.04$"), 
                            (133, sig_pca, "Sigmoid kernel, $\gamma=10^{-3}, r=1$")):
       
    PCA_train_x = PCA(2).fit_transform(train_scaled)
    plt.subplot(subplot)
    plt.title(title, fontsize=14)
    plt.scatter(PCA_train_x[:, 0], PCA_train_x[:, 1], c=target, cmap="nipy_spectral_r")
    plt.xlabel("$z_1$", fontsize=18)
    if subplot == 131:
        plt.ylabel("$z_2$", fontsize=18, rotation=0)
    plt.grid(True)

plt.show()

# %% [markdown]
# ## Data Augmentation

# %%
def augment(x,y,t=2):
    xs,xn = [],[]
    for i in range(t):
        mask = y>0
        x1 = x[mask].copy()
        ids = np.arange(x1.shape[0])
        for c in range(x1.shape[1]):
            np.random.shuffle(ids)
            x1[:,c] = x1[ids][:,c]
        xs.append(x1)

    for i in range(t//2):
        mask = y==0
        x1 = x[mask].copy()
        ids = np.arange(x1.shape[0])
        for c in range(x1.shape[1]):
            np.random.shuffle(ids)
            x1[:,c] = x1[ids][:,c]
        xn.append(x1)

    xs = np.vstack(xs)
    xn = np.vstack(xn)
    ys = np.ones(xs.shape[0])
    yn = np.zeros(xn.shape[0])
    x = np.vstack([x,xs,xn])
    y = np.concatenate([y,ys,yn])
    return x,y

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold,KFold

# %% [markdown]
# ### Applying LGBM model
# -

# %%
param = {
    'bagging_freq': 5,
    'bagging_fraction': 0.335,
    'boost_from_average':'false',
    'boost': 'gbdt',
    'feature_fraction': 0.041,
    'learning_rate': 0.0083,
    'max_depth': -1,
    'metric':'auc',
    'min_data_in_leaf': 80,
    'min_sum_hessian_in_leaf': 10.0,
    'num_leaves': 13,
    'num_threads': 8,
    'tree_learner': 'serial',
    'objective': 'binary', 
    'verbosity': -1
}

# %%
cols = (feature_importance_df[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)
best_features = feature_importance_df.loc[feature_importance_df.feature.isin(cols)]

plt.figure(figsize=(14,26))
sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance",ascending=False))
plt.title('LightGBM Features (averaged over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')

# %%
num_folds = 11
features = [c for c in train.columns if c not in ['ID_code', 'target']]

folds = KFold(n_splits=num_folds, random_state=2319)
oof = np.zeros(len(train))
getVal = np.zeros(len(train))
predictions = np.zeros(len(target))
feature_importance_df = pd.DataFrame()

print('Light GBM Model')
for fold_, (trn_idx, val_idx) in enumerate(folds.split(train.values, target.values)):
    
    X_train, y_train = train.iloc[trn_idx][features], target.iloc[trn_idx]
    X_valid, y_valid = train.iloc[val_idx][features], target.iloc[val_idx]
    
    X_tr, y_tr = augment(X_train.values, y_train.values)
    X_tr = pd.DataFrame(X_tr)
    print("Fold idx:{}".format(fold_ + 1))
    trn_data = lgb.Dataset(X_tr, label=y_tr)
    val_data = lgb.Dataset(X_valid, label=y_valid)
    
    clf = lgb.train(param, trn_data, 10000, valid_sets = [trn_data, val_data], verbose_eval=500, early_stopping_rounds = 400)
    oof[val_idx] = clf.predict(train.iloc[val_idx][features], num_iteration=clf.best_iteration)
    getVal[val_idx]+= clf.predict(train.iloc[val_idx][features], num_iteration=clf.best_iteration) / folds.n_splits
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = features
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(test[features], num_iteration=clf.best_iteration) / folds.n_splits

print("CV score: {:<8.5f}".format(roc_auc_score(target, oof)))
# Out:
# Light GBM Model
# Fold idx:1
# Training until validation scores don't improve for 400 rounds.
# [500]	training's auc: 0.886682	valid_1's auc: 0.874104
# [1000]	training's auc: 0.892982	valid_1's auc: 0.880073
# [1500]	training's auc: 0.897487	valid_1's auc: 0.884255
# [2000]	training's auc: 0.900914	valid_1's auc: 0.887413
# [2500]	training's auc: 0.903656	valid_1's auc: 0.889685
# [3000]	training's auc: 0.905809	valid_1's auc: 0.891286
# [3500]	training's auc: 0.907787	valid_1's auc: 0.892848
# [4000]	training's auc: 0.909482	valid_1's auc: 0.894239
# [4500]	training's auc: 0.910933	valid_1's auc: 0.895256
# [5000]	training's auc: 0.912334	valid_1's auc: 0.896227
# [5500]	training's auc: 0.913581	valid_1's auc: 0.897129
# [6000]	training's auc: 0.914743	valid_1's auc: 0.897725
# [6500]	training's auc: 0.915854	valid_1's auc: 0.898356
# [7000]	training's auc: 0.916874	valid_1's auc: 0.898967
# [7500]	training's auc: 0.917859	valid_1's auc: 0.899335
# [8000]	training's auc: 0.918772	valid_1's auc: 0.899642
# [8500]	training's auc: 0.919674	valid_1's auc: 0.899807
# [9000]	training's auc: 0.920538	valid_1's auc: 0.900063
# [9500]	training's auc: 0.921387	valid_1's auc: 0.900304
# [10000]	training's auc: 0.922222	valid_1's auc: 0.90053
# Did not meet early stopping. Best iteration is:
# [10000]	training's auc: 0.922222	valid_1's auc: 0.90053
# Fold idx:2
# Training until validation scores don't improve for 400 rounds.
# [500]	training's auc: 0.887139	valid_1's auc: 0.876462
# [1000]	training's auc: 0.893633	valid_1's auc: 0.882359
# [1500]	training's auc: 0.898015	valid_1's auc: 0.885931
# [2000]	training's auc: 0.901483	valid_1's auc: 0.888174
# [2500]	training's auc: 0.904255	valid_1's auc: 0.889951
# [3000]	training's auc: 0.9064	valid_1's auc: 0.89109
# [3500]	training's auc: 0.908374	valid_1's auc: 0.892623
# [4000]	training's auc: 0.910087	valid_1's auc: 0.893663
# [4500]	training's auc: 0.911544	valid_1's auc: 0.894304
# [5000]	training's auc: 0.912958	valid_1's auc: 0.895021
# [5500]	training's auc: 0.91422	valid_1's auc: 0.895566
# [6000]	training's auc: 0.91534	valid_1's auc: 0.896206
# [6500]	training's auc: 0.916435	valid_1's auc: 0.896718
# [7000]	training's auc: 0.917468	valid_1's auc: 0.897147
# [7500]	training's auc: 0.918433	valid_1's auc: 0.897404
# [8000]	training's auc: 0.919345	valid_1's auc: 0.897797
# [8500]	training's auc: 0.920214	valid_1's auc: 0.897968
# [9000]	training's auc: 0.921076	valid_1's auc: 0.898101
# [9500]	training's auc: 0.921925	valid_1's auc: 0.898275
# [10000]	training's auc: 0.922722	valid_1's auc: 0.898372
# Did not meet early stopping. Best iteration is:
# [10000]	training's auc: 0.922722	valid_1's auc: 0.898372
# Fold idx:3
# Training until validation scores don't improve for 400 rounds.
# [500]	training's auc: 0.886251	valid_1's auc: 0.867334
# [1000]	training's auc: 0.892971	valid_1's auc: 0.872687
# [1500]	training's auc: 0.897399	valid_1's auc: 0.876592
# [2000]	training's auc: 0.900874	valid_1's auc: 0.880302
# [2500]	training's auc: 0.903656	valid_1's auc: 0.882817
# [3000]	training's auc: 0.905783	valid_1's auc: 0.884606
# [3500]	training's auc: 0.907773	valid_1's auc: 0.886177
# [4000]	training's auc: 0.90948	valid_1's auc: 0.88731
# [4500]	training's auc: 0.911013	valid_1's auc: 0.888187
# [5000]	training's auc: 0.912456	valid_1's auc: 0.889034
# [5500]	training's auc: 0.913696	valid_1's auc: 0.889689
# [6000]	training's auc: 0.914867	valid_1's auc: 0.890343
# [6500]	training's auc: 0.915939	valid_1's auc: 0.890728
# [7000]	training's auc: 0.916969	valid_1's auc: 0.891233
# [7500]	training's auc: 0.917962	valid_1's auc: 0.891588
# [8000]	training's auc: 0.918893	valid_1's auc: 0.891947
# [8500]	training's auc: 0.919804	valid_1's auc: 0.892242
# [9000]	training's auc: 0.920671	valid_1's auc: 0.892452
# [9500]	training's auc: 0.921549	valid_1's auc: 0.89264
# [10000]	training's auc: 0.922333	valid_1's auc: 0.892781
# Did not meet early stopping. Best iteration is:
# [10000]	training's auc: 0.922333	valid_1's auc: 0.892781
# Fold idx:4
# Training until validation scores don't improve for 400 rounds.
# [500]	training's auc: 0.886274	valid_1's auc: 0.880445
# [1000]	training's auc: 0.893051	valid_1's auc: 0.885174
# [1500]	training's auc: 0.897443	valid_1's auc: 0.888959
# [2000]	training's auc: 0.900883	valid_1's auc: 0.892455
# [2500]	training's auc: 0.903623	valid_1's auc: 0.894757
# [3000]	training's auc: 0.905784	valid_1's auc: 0.896322
# [3500]	training's auc: 0.907742	valid_1's auc: 0.897636
# [4000]	training's auc: 0.909479	valid_1's auc: 0.898527
# [4500]	training's auc: 0.910971	valid_1's auc: 0.899544
# [5000]	training's auc: 0.912366	valid_1's auc: 0.900327
# [5500]	training's auc: 0.913592	valid_1's auc: 0.900842
# [6000]	training's auc: 0.91474	valid_1's auc: 0.901539
# [6500]	training's auc: 0.915853	valid_1's auc: 0.902013
# [7000]	training's auc: 0.916865	valid_1's auc: 0.902316
# [7500]	training's auc: 0.917823	valid_1's auc: 0.902456
# [8000]	training's auc: 0.918771	valid_1's auc: 0.902636
# [8500]	training's auc: 0.91966	valid_1's auc: 0.902825
# [9000]	training's auc: 0.920526	valid_1's auc: 0.903065
# [9500]	training's auc: 0.921385	valid_1's auc: 0.903192
# [10000]	training's auc: 0.922211	valid_1's auc: 0.903208
# Did not meet early stopping. Best iteration is:
# [10000]	training's auc: 0.922211	valid_1's auc: 0.903208
# Fold idx:5
# Training until validation scores don't improve for 400 rounds.
# [500]	training's auc: 0.886717	valid_1's auc: 0.87499
# [1000]	training's auc: 0.893212	valid_1's auc: 0.880118
# [1500]	training's auc: 0.897685	valid_1's auc: 0.884532
# [2000]	training's auc: 0.901194	valid_1's auc: 0.887544
# [2500]	training's auc: 0.904091	valid_1's auc: 0.889846
# [3000]	training's auc: 0.906271	valid_1's auc: 0.891557
# [3500]	training's auc: 0.908288	valid_1's auc: 0.892951
# [4000]	training's auc: 0.910035	valid_1's auc: 0.894046
# [4500]	training's auc: 0.911531	valid_1's auc: 0.895197
# [5000]	training's auc: 0.912986	valid_1's auc: 0.895889
# [5500]	training's auc: 0.914214	valid_1's auc: 0.896376
# [6000]	training's auc: 0.915426	valid_1's auc: 0.896889
# [6500]	training's auc: 0.916533	valid_1's auc: 0.897466
# [7000]	training's auc: 0.917551	valid_1's auc: 0.897747
# [7500]	training's auc: 0.91852	valid_1's auc: 0.898044
# [8000]	training's auc: 0.919465	valid_1's auc: 0.898385
# [8500]	training's auc: 0.920372	valid_1's auc: 0.898608
# [9000]	training's auc: 0.921232	valid_1's auc: 0.898714
# [9500]	training's auc: 0.922068	valid_1's auc: 0.89894
# [10000]	training's auc: 0.922875	valid_1's auc: 0.899007
# Did not meet early stopping. Best iteration is:
# [10000]	training's auc: 0.922875	valid_1's auc: 0.899007
# Fold idx:6
# Training until validation scores don't improve for 400 rounds.
# [500]	training's auc: 0.88563	valid_1's auc: 0.878448
# [1000]	training's auc: 0.89228	valid_1's auc: 0.884067
# [1500]	training's auc: 0.89667	valid_1's auc: 0.888206
# [2000]	training's auc: 0.900176	valid_1's auc: 0.891307
# [2500]	training's auc: 0.902948	valid_1's auc: 0.893134
# [3000]	training's auc: 0.905187	valid_1's auc: 0.894762
# [3500]	training's auc: 0.907186	valid_1's auc: 0.89626
# [4000]	training's auc: 0.908886	valid_1's auc: 0.897239
# [4500]	training's auc: 0.910349	valid_1's auc: 0.898277
# [5000]	training's auc: 0.911773	valid_1's auc: 0.899026
# [5500]	training's auc: 0.913058	valid_1's auc: 0.899689
# [6000]	training's auc: 0.91425	valid_1's auc: 0.90012
# [6500]	training's auc: 0.915365	valid_1's auc: 0.900495
# [7000]	training's auc: 0.916384	valid_1's auc: 0.900927
# [7500]	training's auc: 0.917374	valid_1's auc: 0.901224
# [8000]	training's auc: 0.918291	valid_1's auc: 0.901561
# [8500]	training's auc: 0.919175	valid_1's auc: 0.901789
# [9000]	training's auc: 0.92005	valid_1's auc: 0.901853
# [9500]	training's auc: 0.920916	valid_1's auc: 0.902027
# [10000]	training's auc: 0.921722	valid_1's auc: 0.902116
# Did not meet early stopping. Best iteration is:
# [10000]	training's auc: 0.921722	valid_1's auc: 0.902116
# Fold idx:7
# Training until validation scores don't improve for 400 rounds.
# [500]	training's auc: 0.886252	valid_1's auc: 0.883571
# [1000]	training's auc: 0.892321	valid_1's auc: 0.889975
# [1500]	training's auc: 0.896685	valid_1's auc: 0.893017
# [2000]	training's auc: 0.900201	valid_1's auc: 0.895846
# [2500]	training's auc: 0.902985	valid_1's auc: 0.898045
# [3000]	training's auc: 0.905158	valid_1's auc: 0.899201
# [3500]	training's auc: 0.907143	valid_1's auc: 0.900514
# [4000]	training's auc: 0.908851	valid_1's auc: 0.90153
# [4500]	training's auc: 0.910323	valid_1's auc: 0.902378
# [5000]	training's auc: 0.911736	valid_1's auc: 0.903058
# [5500]	training's auc: 0.912968	valid_1's auc: 0.903572
# [6000]	training's auc: 0.914098	valid_1's auc: 0.903947
# [6500]	training's auc: 0.915208	valid_1's auc: 0.904205
# [7000]	training's auc: 0.916225	valid_1's auc: 0.904424
# [7500]	training's auc: 0.917196	valid_1's auc: 0.904646
# [8000]	training's auc: 0.918146	valid_1's auc: 0.904862
# [8500]	training's auc: 0.919049	valid_1's auc: 0.90495
# [9000]	training's auc: 0.919897	valid_1's auc: 0.905036
# [9500]	training's auc: 0.920733	valid_1's auc: 0.905171
# [10000]	training's auc: 0.921581	valid_1's auc: 0.905188
# Did not meet early stopping. Best iteration is:
# [10000]	training's auc: 0.921581	valid_1's auc: 0.905188
# Fold idx:8
# Training until validation scores don't improve for 400 rounds.
# [500]	training's auc: 0.886703	valid_1's auc: 0.874876
# [1000]	training's auc: 0.893035	valid_1's auc: 0.881233
# [1500]	training's auc: 0.897287	valid_1's auc: 0.885511
# [2000]	training's auc: 0.900788	valid_1's auc: 0.888335
# [2500]	training's auc: 0.90354	valid_1's auc: 0.890825
# [3000]	training's auc: 0.905684	valid_1's auc: 0.892539
# [3500]	training's auc: 0.90771	valid_1's auc: 0.894012
# [4000]	training's auc: 0.909426	valid_1's auc: 0.895155
# [4500]	training's auc: 0.910955	valid_1's auc: 0.896054
# [5000]	training's auc: 0.912381	valid_1's auc: 0.896871
# [5500]	training's auc: 0.91366	valid_1's auc: 0.897471
# [6000]	training's auc: 0.914805	valid_1's auc: 0.89793
# [6500]	training's auc: 0.9159	valid_1's auc: 0.898413
# [7000]	training's auc: 0.916894	valid_1's auc: 0.898843
# [7500]	training's auc: 0.917893	valid_1's auc: 0.899067
# [8000]	training's auc: 0.918812	valid_1's auc: 0.899282
# [8500]	training's auc: 0.919684	valid_1's auc: 0.899398
# [9000]	training's auc: 0.920584	valid_1's auc: 0.899545
# [9500]	training's auc: 0.921445	valid_1's auc: 0.899603
# [10000]	training's auc: 0.922263	valid_1's auc: 0.899728
# Did not meet early stopping. Best iteration is:
# [10000]	training's auc: 0.922263	valid_1's auc: 0.899728
# Fold idx:9
# Training until validation scores don't improve for 400 rounds.
# [500]	training's auc: 0.886319	valid_1's auc: 0.877555
# [1000]	training's auc: 0.892783	valid_1's auc: 0.884364
# [1500]	training's auc: 0.897144	valid_1's auc: 0.888372
# [2000]	training's auc: 0.90067	valid_1's auc: 0.891226
# [2500]	training's auc: 0.903481	valid_1's auc: 0.893807
# [3000]	training's auc: 0.905643	valid_1's auc: 0.895417
# [3500]	training's auc: 0.907598	valid_1's auc: 0.897115
# [4000]	training's auc: 0.90931	valid_1's auc: 0.898543
# [4500]	training's auc: 0.910804	valid_1's auc: 0.899395
# [5000]	training's auc: 0.912215	valid_1's auc: 0.900302
# [5500]	training's auc: 0.913484	valid_1's auc: 0.901148
# [6000]	training's auc: 0.914638	valid_1's auc: 0.901804
# [6500]	training's auc: 0.915756	valid_1's auc: 0.902288
# [7000]	training's auc: 0.916771	valid_1's auc: 0.902773
# [7500]	training's auc: 0.917732	valid_1's auc: 0.903078
# [8000]	training's auc: 0.918665	valid_1's auc: 0.903351
# [8500]	training's auc: 0.919541	valid_1's auc: 0.903396
# [9000]	training's auc: 0.920404	valid_1's auc: 0.903552
# [9500]	training's auc: 0.921267	valid_1's auc: 0.903733
# [10000]	training's auc: 0.922097	valid_1's auc: 0.903797
# Did not meet early stopping. Best iteration is:
# [10000]	training's auc: 0.922097	valid_1's auc: 0.903797
# Fold idx:10
# Training until validation scores don't improve for 400 rounds.
# [500]	training's auc: 0.886112	valid_1's auc: 0.880272
# [1000]	training's auc: 0.892441	valid_1's auc: 0.886983
# [1500]	training's auc: 0.896788	valid_1's auc: 0.891133
# [2000]	training's auc: 0.900242	valid_1's auc: 0.893802
# [2500]	training's auc: 0.903057	valid_1's auc: 0.896163
# [3000]	training's auc: 0.905253	valid_1's auc: 0.89803
# [3500]	training's auc: 0.907255	valid_1's auc: 0.899539
# [4000]	training's auc: 0.909032	valid_1's auc: 0.90082
# [4500]	training's auc: 0.91051	valid_1's auc: 0.901688
# [5000]	training's auc: 0.911912	valid_1's auc: 0.902571
# [5500]	training's auc: 0.913152	valid_1's auc: 0.903262
# [6000]	training's auc: 0.914312	valid_1's auc: 0.903763
# [6500]	training's auc: 0.915421	valid_1's auc: 0.904086
# [7000]	training's auc: 0.916467	valid_1's auc: 0.904523
# [7500]	training's auc: 0.917436	valid_1's auc: 0.904963
# [8000]	training's auc: 0.918365	valid_1's auc: 0.905286
# [8500]	training's auc: 0.919265	valid_1's auc: 0.905483
# [9000]	training's auc: 0.920125	valid_1's auc: 0.905632
# [9500]	training's auc: 0.920987	valid_1's auc: 0.905796
# [10000]	training's auc: 0.921807	valid_1's auc: 0.905898
# Did not meet early stopping. Best iteration is:
# [10000]	training's auc: 0.921807	valid_1's auc: 0.905898
# Fold idx:11
# Training until validation scores don't improve for 400 rounds.
# [500]	training's auc: 0.886112	valid_1's auc: 0.87837
# [1000]	training's auc: 0.892701	valid_1's auc: 0.883348
# [1500]	training's auc: 0.897073	valid_1's auc: 0.886739
# [2000]	training's auc: 0.900572	valid_1's auc: 0.889067
# [2500]	training's auc: 0.903319	valid_1's auc: 0.891205
# [3000]	training's auc: 0.90554	valid_1's auc: 0.892993
# [3500]	training's auc: 0.907556	valid_1's auc: 0.894229
# [4000]	training's auc: 0.909284	valid_1's auc: 0.895437
# [4500]	training's auc: 0.910744	valid_1's auc: 0.896136
# [5000]	training's auc: 0.91216	valid_1's auc: 0.896846
# [5500]	training's auc: 0.913411	valid_1's auc: 0.897525
# [6000]	training's auc: 0.914584	valid_1's auc: 0.898063
# [6500]	training's auc: 0.915705	valid_1's auc: 0.898485
# [7000]	training's auc: 0.916748	valid_1's auc: 0.89886
# [7500]	training's auc: 0.917712	valid_1's auc: 0.899132
# [8000]	training's auc: 0.918646	valid_1's auc: 0.899328
# [8500]	training's auc: 0.919559	valid_1's auc: 0.899645
# [9000]	training's auc: 0.920446	valid_1's auc: 0.899723
# [9500]	training's auc: 0.921337	valid_1's auc: 0.899889
# [10000]	training's auc: 0.922141	valid_1's auc: 0.90015
# Did not meet early stopping. Best iteration is:
# [10000]	training's auc: 0.922141	valid_1's auc: 0.90015
# CV score: 0.90096

# %% [markdown]
# Above code has taken five hours of training on google colab don't use it in your local system

# %% [markdown]
# #### Making our submission file named as submission1.csv

# %%
#num_sub = 26
print('Saving the Submission File')
sub = pd.DataFrame({"ID_code": test.ID_code.values})
sub["target"] = predictions
sub.to_csv('submission1.csv'.format(), index=False)
# Out:
# Saving the Submission File

# %%
submission=pd.read_csv('submission1.csv')

# %%
submission.head(10)
# Out:
#   ID_code    target
# 0  test_0  0.143574
# 1  test_1  0.286492
# 2  test_2  0.241039
# 3  test_3  0.281912
# 4  test_4  0.065084
# 5  test_5  0.003493
# 6  test_6  0.009824
# 7  test_7  0.243036
# 8  test_8  0.004341
# 9  test_9  0.013294
